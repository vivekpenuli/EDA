# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekpenuli/EDA/blob/master/EDA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
url='https://raw.githubusercontent.com/vaquarkhan/Applied-AI-Course/master/ExploratoryDataAnalysis(EDA)/iris.csv'
flower=pd.read_csv(url)

# %%
flower.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import seaborn as sns
ax = sns.scatterplot(x="sepal_length", y="sepal_width", data=flower)
# problem : different calsses aare not visualize properly

# %%
ax = sns.scatterplot(x="sepal_length", y="sepal_width", hue="species",data=flower)
# classes are differentiate based on the specices

# %%
ax = sns.scatterplot(x="sepal_length", y="sepal_width", hue="species",style='species',data=flower)
# better beacuse here each calsses is assign different shapes

# %% [markdown]
# # msost important

# %%
ax = sns.scatterplot(x="sepal_length", y="sepal_width", hue="species",size='species',data=flower)
# here we can clearly see that setosa is much cluster around same values while rest have few examples for same values

# %%
g = sns.FacetGrid(flower, col="species",  hue="species")
g = (g.map(plt.scatter,'sepal_length','sepal_width', edgecolor="w")
      .add_legend())

# %%
se=flower[flower.sepal_length==5.0]

# %%
se
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 4            5.0          3.6           1.4          0.2      setosa
# 7            5.0          3.4           1.5          0.2      setosa
# 25           5.0          3.0           1.6          0.2      setosa
# 26           5.0          3.4           1.6          0.4      setosa
# 35           5.0          3.2           1.2          0.2      setosa
# 40           5.0          3.5           1.3          0.3      setosa
# 43           5.0          3.5           1.6          0.6      setosa
# 49           5.0          3.3           1.4          0.2      setosa
# 60           5.0          2.0           3.5          1.0  versicolor
# 93           5.0          2.3           3.3          1.0  versicolor

# %%
se["species"].value_counts()
# Out:
# setosa        8
# versicolor    2
# Name: species, dtype: int64

# %%
se2=flower[flower.sepal_length==7.9]

# %%
se2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica

# %%
se2["species"].value_counts()
# Out:
# virginica    1
# Name: species, dtype: int64

# %%
flower[flower.sepal_length==6.0]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 62            6.0          2.2           4.0          1.0  versicolor
# 78            6.0          2.9           4.5          1.5  versicolor
# 83            6.0          2.7           5.1          1.6  versicolor
# 85            6.0          3.4           4.5          1.6  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 138           6.0          3.0           4.8          1.8   virginica

# %%
import matplotlib.pyplot as plt

# pairwise scatter plot: Pair-Plot
# Dis-advantages: 
##Can be used when number of features are high.
##Cannot visualize higher dimensional patterns in 3-D and 4-D. 
#Only possible to view 2D patterns.
plt.close();
sns.set_style("whitegrid");
sns.pairplot(flower, hue="species", size=3);
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(flower, hue='species', size=4)     # hue = on waht basis your density plot drawn
g = (g.map(sns.distplot,'petal_length').add_legend())  # here density plot is shown for petal length
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(flower, hue='species', size=4)    
g = (g.map(sns.distplot,'petal_width').add_legend())
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(flower, hue='species', size=4)    
g = (g.map(sns.distplot,'sepal_width').add_legend())
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(flower, hue='species', size=4)    
g = (g.map(sns.distplot,'sepal_length').add_legend())
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # box plot

# %%
sns.boxplot(x='species',y='petal_length', data=flower)
plt.show()

# %% [markdown]
# [link text](https://github.com/bhattbhavesh91/violin-plot-seaborn/blob/master/violin-plot-seaborn-notebook.ipynb)

# %% [markdown]
# # violin plot
# -> cobination of histogram and box-plot

# %%
sns.violinplot(x="species", y="petal_length", data=flower, size=8)
plt.show()
