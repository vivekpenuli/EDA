# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekpenuli/EDA/blob/master/EDA_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url='https://raw.githubusercontent.com/vivekpenuli/EDA/master/tips.csv'

# %%
import pandas as pd
tips=pd.read_csv(url)
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
kapil=tips.head(5)

# %%
kapil
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.barplot(x="day", y="total_bill", data=kapil)

# %%
kapil=tips[tips['day']=='Sun']

# %%
kapil
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [76 rows x 7 columns]

# %%
kapil.median()
# Out:
# total_bill    19.63
# tip            3.15
# size           2.00
# dtype: float64

# %%
from statistics import median

# %%
ax = sns.barplot(x="day", y="total_bill", data=kapil,estimator=median) # if we are intrested in finding median

# %%
kapil.mean()
# Out:
# total_bill    21.410000
# tip            3.255132
# size           2.842105
# dtype: float64

# %%
ax = sns.barplot(x="day", y="total_bill", data=kapil)  # by default it will use mean to draw the bar chart

# %%
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.barplot(x="sex", y="total_bill", data=tips)

# %%
ax = sns.barplot(x="day", y="total_bill",hue='sex', data=tips)

# %%
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.barplot(x="day", y="total_bill", data=tips)
ax = sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")

# %%
sns.swarmplot(data=tips, x='day', y='total_bill')
plt.margins(0.02)
plt.xlabel('days')
plt.ylabel('total_bill')
# Out:
# Text(0, 0.5, 'total_bill')

# %%
ax = sns.boxplot(x=tips["total_bill"])

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.boxplot(x="day", y="total_bill", hue='sex',data=tips)

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="sex",
                 data=tips, palette="Set3")

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="time",
                 data=tips,)

# %%
tips["weekend"] = tips["day"].isin(["Thur", "Sun"])
ax = sns.boxplot(x="day", y="total_bill", hue="weekend",
                 data=tips, dodge=False)

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)
ax = sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")

# %%
ax = sns.boxplot(x="sex", y="total_bill", data=tips,hue='smoker')

# %% [markdown]
# Use catplot() to combine a boxplot() and a FacetGrid. This allows grouping within additional categorical variables. Using catplot() is safer than using FacetGrid directly, as it ensures synchronization of variable order across facets:

# %%
g = sns.catplot(x="sex", y="total_bill",
                hue="smoker", col="time",      # here two columns created one for dinner and other for lunch
                data=tips, kind="box",               # so in catplot we use 4 variables 
                height=4, aspect=.7);

# %% [markdown]
# # histogram

# %%
g = sns.FacetGrid(tips, hue='sex', size=4)     # hue = on waht basis your density plot drawn
g = (g.map(sns.distplot,'total_bill').add_legend())
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.distplot(tips.total_bill, kde=True)

# %%
apple=(tips[(tips.day == 'Fri') & (tips.smoker == 'Yes')]['total_bill'])

# %%
apple
# Out:
# 90     28.97
# 92      5.75
# 93     16.32
# 95     40.17
# 96     27.28
# 97     12.03
# 98     21.01
# 100    11.35
# 101    15.38
# 220    12.16
# 221    13.42
# 222     8.58
# 224    13.42
# 225    16.27
# 226    10.09
# Name: total_bill, dtype: float64

# %%
bana=(tips[(tips.day == 'Fri') & (tips.smoker == 'Yes')])

# %%
bana
# Out:
#      total_bill   tip     sex smoker  day    time  size  weekend
# 90        28.97  3.00    Male    Yes  Fri  Dinner     2    False
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2    False
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2    False
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4    False
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2    False
# 97        12.03  1.50    Male    Yes  Fri  Dinner     2    False
# 98        21.01  3.00    Male    Yes  Fri  Dinner     2    False
# 100       11.35  2.50  Female    Yes  Fri  Dinner     2    False
# 101       15.38  3.00  Female    Yes  Fri  Dinner     2    False
# 220       12.16  2.20    Male    Yes  Fri   Lunch     2    False
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2    False
# 222        8.58  1.92    Male    Yes  Fri   Lunch     1    False
# 224       13.42  1.58    Male    Yes  Fri   Lunch     2    False
# ...

# %%
sns.distplot(tips[(tips.day == 'Fri') & (tips.smoker == 'Yes')]['total_bill'])

# %%
sns.distplot(tips[(tips.day == 'Fri') & (tips.smoker == 'No')]['total_bill'])

# %%
sns.distplot(tips[(tips.day == 'Sun') & (tips.smoker == 'Yes')]['total_bill'])

# %%
sns.distplot(tips[(tips.day == 'Sun') & (tips.smoker == 'No')]['total_bill'])

# %% [markdown]
# # violin plot
# [link text](https://towardsdatascience.com/violin-plots-explained-fb1d115e023d)

# %%
ax = sns.violinplot(x=tips["total_bill"])

# %%
ax = sns.violinplot(x=tips["total_bill"])

# %%
ax = sns.violinplot(tips[(tips.day == 'Fri') & (tips.smoker == 'Yes')]['total_bill'])

# %%
ax = sns.violinplot(tips[(tips.day == 'Fri') & (tips.smoker == 'No')]['total_bill'])

# %%
ax = sns.violinplot(x=tips.day, y=tips.total_bill,hue='sex',
                    data=tips, split=True)

# %% [markdown]
# we can use this method th get box plot info from violin plot more easly

# %%
ax = sns.violinplot(x="day", y="total_bill", hue="sex",
                    data=tips, split=True,
                    scale="count", inner="quartile")

# %%
sns.scatterplot(x='tip',y='total_bill',data=tips)

# %%
ax = tips.plot.hexbin(x='tip', y='total_bill',
                         gridsize=30, sharex=False, figsize=(5, 4))
ax.set_xlabel('Finished Square Feet')
ax.set_ylabel('Tax Assessed Value')

plt.tight_layout()
plt.show()
